# %% [markdown]
# <a href="https://colab.research.google.com/github/dewi-ikrimah/pm-turi1-eda/blob/main/PM_TuRi1_EDA_Dewi-Ikrimah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mengecek environment & pustaka dasar
import numpy as np
import pandas as pd
import sklearn

print('NumPy:', np.__version__)
print('pandas:', pd.__version__)
print('scikit-learn:', sklearn.__version__)
# Out:
# NumPy: 2.1.3
# pandas: 2.2.3
# scikit-learn: 1.6.1
